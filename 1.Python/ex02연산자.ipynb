# %% [markdown]
# ## 연산자
# ![image.png](attachment:image.png)

# %%
# 문자열 더하기
str1="안녕"
str2="하세요"
str1+str2
# Out:
# '안녕하세요'

# %%
str1*30
# Out:
# '안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕'

# %%
str1="1"
str2="3"
str1+str2
# Out:
# '13'

# %%
#숫자와 문자열 더하기(강제 형변환해야함)
num1=10
num2="7"
str(num1)+num2
# Out:
# '107'

# %%
# input() 함수
# input("안내문구>>")

# 1. input() 기본 반환값은 문자형(str)이다!
# 2. input()에서 나온 반환값을 연산하기 위해서는 형변환이 필요하다
# 3. input()는 실행을 완료시켜야지만 다음 코드 진행 가능
input("입력해주세요 >>")
# Out:
# 입력해주세요 >>10
# '10'

# %%
# 파이썬 나누기 기호
num1=10
num2=7
print(f"나누기:{num1/num2}")
print(f"몫:{num1//num2}")
print(f"나머지:{num1%num2}")

# %%
#num1과 num2를 키보드로 입력받아서 결과를 계산하시오
num1=int(input("정수를 입력하세요>>"))
num2=int(input("정수를 입력하세요>>"))
print(f"더하기결과:{(num1)+(num2)}")
print(f"빼기결과:{(num1)-(num2)}")
print(f"곱하기결과:{(num1)*(num2)}")
print(f"나누기결과:{(num1)/(num2)}")
print(f"몫 결과:{(num1)//(num2)}")
print(f"나머지결과:{(num1)%(num2)}")
print(f"제곱결과:{num1 ** num2}")
# Out:
# 정수를 입력하세요>>10
# 정수를 입력하세요>>4
# 더하기결과:14
# 빼기결과:6
# 곱하기결과:40
# 나누기결과:2.5
# 몫 결과:2
# 나머지결과:2
# 제곱결과:10000

# %%
# 관계연산자
num1 >= num2
# Out:
# True

# %%
# 복합연산자
# 값을 누적시키기 위해 사용
# 코드를 줄이기 위해 사용
a+=1
a
# Out:
# 11

# %%
# 논리연산자
# and, or, not
True and True

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %%
# 멤버연산자
# 1,2,3,4 중에 4가 들어있니?
4 in [1,2,3,4]
# Out:
# True

# %% [markdown]
# ### 삼항연산자
# - `(강세표): 물결기호(~) 아래에 있음(코드를 마크다운 셀에 기록으로 남기고자 하는 경우 활용)
# ```python
# a if 조건식 else b
# ```
# - 조건식이 True인 경우 a(False인 경우 b)로 감

# %%
score = 60
print("합격") if score>60 else print("불합격")
# Out:
# '불합격'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1=int(input("정수 입력>>"))
f"{num1}은 홀수입니다"if num1%2==1 else f"{num1}은 짝수입니다"
# Out:
# 정수 입력>>25
# '25은 홀수입니다'
