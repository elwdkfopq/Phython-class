# %% [markdown]
# #### 0.matplotlib 패키지 import

# %%
import matplotlib.pyplot as plt
# 한글폰트 적용
plt.rcParams['font.family' ]='Malgun Gothic'
# 마이너스 기호 적용
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# #### 1. maplotlib를 사용하는 순서
# - 1. 그림이 그려질 그림판을 셋팅
# - 2. 실제로 그려질 차트 설정
# - 3. 그림을 그려달라는 명령어

# %% [markdown]
# #### 2. 선그래프

# %%
plt.figure(figsize=(10,5)) # 가로,세로(인치)
x = [1,2,3]
y = [1,2,3]
plt.plot(x,y, ls=":", # - / -- / -. / :
         c="red",
         lw=5,
         marker="", # marker o / ^ / * / >
        meo='green',
        ms=20,
        mew=4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       2 x = [1,2,3]
#       3 y = [1,2,3]
# ----> 4 plt.plot(x,y, ls=":", # - / -- / -. / :
#       5          c="red",
#       6          lw=5,
#       7          marker="",
#       8         meo='green',
#       9         ms=20,
#      10         mew=4) # marker o / ^ / * / >
#      11 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 여러개를 차트에 그리기
plt.figure(figsize=(10,5))

plt.plot([1,2,3],[1,2,3], label="인구수")
plt.plot([1,2,3],[1,4,9], label="생산량")

# 범례
plt.legend()

plt.show()

# %%
plt.plot([1,2,3],[1,4,9], label="생산량")

# %% [markdown]
# #### 3. bar차트

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,5))

# bar 차트 -> 범주형데이터와 수치형데이터를 그릴때 
x=['A형','B형','AB형','O형']
y=[10,5,7,3]

plt.bar(x,y)
plt.xlabel("혈액형")
plt.ylabel("인원수")
plt.title("우리반 혈액형 분포")
plt.grid()
plt.show()

# %%
import pandas as pd
cctv = pd.read_csv("./data/광주광역시_CCTV_20231231.CSV",encoding="euc-kr")
cctv.head()
# Out:
#          관리기관명         소재지지번주소        소재지도로명주소  카메라대수 카메라화소  촬영방면 보관일수  설치연도  \
# 0  광주광역시 사회재난과   광산구 광산동 666-7     광산구 고봉로 905      2  200만  360도  30일  2018
# 1  광주광역시 사회재난과  광산구 도덕동 320-15     광산구 삼도로 342      1  200만  360도  30일  2013
# 2  광주광역시 사회재난과  광산구 도덕동 320-15     광산구 삼도로 342      1  200만  360도  30일  2022
# 3  광주광역시 사회재난과  광산구 도산동 1128-4   광산구 도산로9번길 58      4  200만  360도  30일  2020
# 4  광주광역시 사회재난과  광산구 도산동 1282-1  광산구 남동길48번길 25      1  200만  360도  30일  2013
#
#           위도          경도     데이터기준일자
# 0  35.225272  126.735854  2023-12-31
# 1  35.162851  126.699911  2023-12-31
# 2  35.162851  126.699911  2023-12-31
# 3  35.127057  126.789353  2023-12-31
# 4  35.130739  126.789865  2023-12-31

# %%
dong= cctv['소재지지번주소'].str.split(" ").str[1]
dong_bul_camera_sum=cctv.groupby(by=dong).sum()
display(dong_bul_camera_sum)
x=dong_bul_camera_sum['소재지지번주소']
y=dong_bul_camera_sum['카메라대수']
display(y)
plt.bar(x,y)
plt.show()
# Out:
#                                                      관리기관명  \
# 소재지지번주소
# 각화동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
# 건국동                                            광주광역시 사회재난과
# 계림동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
# 고룡동                                            광주광역시 사회재난과
# 광산동           광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과
# ...                                                    ...
# 화장동                                            광주광역시 사회재난과
# 화정동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
# 황금동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
# 효령동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
# 흑석동      광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주광역시 사회재난과광주...
#
#                                                    소재지지번주소  \
# 소재지지번주소
# 각화동      북구 각화동 149-8북구 각화동 337북구 각화동 337북구 각화동 570-19북...
# 건국동                                            북구 건국동 2990
# ...
